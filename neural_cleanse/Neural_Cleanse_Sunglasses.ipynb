# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# !git clone "https://github.com/bolunwang/backdoor"
# Out:
# Cloning into 'backdoor'...
# remote: Enumerating objects: 90, done.
# remote: Total 90 (delta 0), reused 0 (delta 0), pack-reused 90
# Unpacking objects: 100% (90/90), done.

# %%
# !git clone "https://github.com/nicholasbennet/ml-cybersec-proj"
# Out:
# Cloning into 'ml-cybersec-proj'...
# remote: Enumerating objects: 84, done.
# remote: Counting objects: 100% (84/84), done.
# remote: Compressing objects: 100% (59/59), done.
# remote: Total 84 (delta 37), reused 60 (delta 22), pack-reused 0
# Unpacking objects: 100% (84/84), done.

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
clean_data_filename='/content/drive/MyDrive/data/clean_test_data.h5'
poisoned_data_filename='/content/drive/MyDrive/data/sunglasses_poisoned_data.h5'
clean_validation_filename='/content/drive/MyDrive/data/clean_validation_data.h5'
#model_filename = '/content/ml-cybersec-proj/models/sunglasses_bd_net.h5'
#model_weight_filename = '/content/ml-cybersec-proj/models/sunglasses_bd_weights.h5'

# %%
import os
import time
# %tensorflow_version 1.x
import numpy as np
import random
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import h5py
import tensorflow as tf
from tensorflow.keras.preprocessing import image
np.random.seed(123)
from tensorflow.keras import backend as K
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.metrics import categorical_accuracy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import UpSampling2D, Cropping2D
from decimal import Decimal
#from tensorflow import set_random_seed
#random.seed(123)
#set_random_seed(123)
tf.compat.v1.disable_eager_execution()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def dump_image(x, filename, format):            #utils_backdoor_file
    img = image.array_to_img(x, scale=False)
    img.save(filename, format)
    return

def fix_gpu_memory(mem_fraction=1):
    
    with tf.compat.v1.Session() as sess:
        from tensorflow.compat.v1.keras import backend as K
        gpu_options = tf.compat.v1.GPUOptions(per_process_gpu_memory_fraction=mem_fraction)
        tf_config = tf.compat.v1.ConfigProto(gpu_options=gpu_options)
        tf_config.gpu_options.allow_growth = True
        tf_config.log_device_placement = False
        tf_config.allow_soft_placement = True
        init_op = tf.compat.v1.global_variables_initializer()
        sess = tf.compat.v1.Session(config=tf_config)
        sess.run(init_op)
        K.set_session(sess)
        return sess

def load_data(data_filename, keys=None):
    ''' assume all datasets are numpy arrays '''
    dataset = {}
    with h5py.File(data_filename, 'r') as hf:
        if keys is None:
            for name in hf:
                dataset[name] = np.array(hf.get(name))
        else:
            for name in keys:
                dataset[name] = np.array(hf.get(name))

    return dataset

# %%
class Visualizer:

    # upsample size, default is 1
    UPSAMPLE_SIZE = 1
    # pixel intensity range of image and preprocessing method
    # raw: [0, 255]
    # mnist: [0, 1]
    # imagenet: imagenet mean centering
    # inception: [-1, 1]
    INTENSITY_RANGE = 'raw'
    # type of regularization of the mask
    REGULARIZATION = 'l1'
    # threshold of attack success rate for dynamically changing cost
    ATTACK_SUCC_THRESHOLD = 0.99
    # patience
    PATIENCE = 10
    # multiple of changing cost, down multiple is the square root of this
    COST_MULTIPLIER = 1.5,
    # if resetting cost to 0 at the beginning
    # default is true for full optimization, set to false for early detection
    RESET_COST_TO_ZERO = True
    # min/max of mask
    MASK_MIN = 0
    MASK_MAX = 1
    # min/max of raw pixel intensity
    COLOR_MIN = 0
    COLOR_MAX = 255
    # number of color channel
    IMG_COLOR = 3
    # whether to shuffle during each epoch
    SHUFFLE = True
    # batch size of optimization
    BATCH_SIZE = 32
    # verbose level, 0, 1 or 2
    VERBOSE = 1
    # whether to return log or not
    RETURN_LOGS = True
    # whether to save last pattern or best pattern
    SAVE_LAST = False
    # epsilon used in tanh
    EPSILON = K.epsilon()
    # early stop flag
    EARLY_STOP = True
    # early stop threshold
    EARLY_STOP_THRESHOLD = 0.99
    # early stop patience
    EARLY_STOP_PATIENCE = 2 * PATIENCE
    # save tmp masks, for debugging purpose
    SAVE_TMP = False
    # dir to save intermediate masks
    TMP_DIR = 'tmp'
    # whether input image has been preprocessed or not
    RAW_INPUT_FLAG = False

    def __init__(self, model, intensity_range, regularization, input_shape,
                 init_cost, steps, mini_batch, lr, num_classes,
                 upsample_size=UPSAMPLE_SIZE,
                 attack_succ_threshold=ATTACK_SUCC_THRESHOLD,
                 patience=PATIENCE, cost_multiplier=COST_MULTIPLIER,
                 reset_cost_to_zero=RESET_COST_TO_ZERO,
                 mask_min=MASK_MIN, mask_max=MASK_MAX,
                 color_min=COLOR_MIN, color_max=COLOR_MAX, img_color=IMG_COLOR,
                 shuffle=SHUFFLE, batch_size=BATCH_SIZE, verbose=VERBOSE,
                 return_logs=RETURN_LOGS, save_last=SAVE_LAST,
                 epsilon=EPSILON,
                 early_stop=EARLY_STOP,
                 early_stop_threshold=EARLY_STOP_THRESHOLD,
                 early_stop_patience=EARLY_STOP_PATIENCE,
                 save_tmp=SAVE_TMP, tmp_dir=TMP_DIR,
                 raw_input_flag=RAW_INPUT_FLAG):

        assert intensity_range in {'imagenet', 'inception', 'mnist', 'raw'}
        assert regularization in {None, 'l1', 'l2'}

        self.model = model
        self.intensity_range = intensity_range
        self.regularization = regularization
        self.input_shape = input_shape
        self.init_cost = init_cost
        self.steps = steps
        self.mini_batch = mini_batch
        self.lr = lr
        self.num_classes = num_classes
        self.upsample_size = upsample_size
        self.attack_succ_threshold = attack_succ_threshold
        self.patience = patience
        self.cost_multiplier_up = cost_multiplier
        self.cost_multiplier_down = cost_multiplier ** 1.5
        self.reset_cost_to_zero = reset_cost_to_zero
        self.mask_min = mask_min
        self.mask_max = mask_max
        self.color_min = color_min
        self.color_max = color_max
        self.img_color = img_color
        self.shuffle = shuffle
        self.batch_size = batch_size
        self.verbose = verbose
        self.return_logs = return_logs
        self.save_last = save_last
        self.epsilon = epsilon
        self.early_stop = early_stop
        self.early_stop_threshold = early_stop_threshold
        self.early_stop_patience = early_stop_patience
        self.save_tmp = save_tmp
        self.tmp_dir = tmp_dir
        self.raw_input_flag = raw_input_flag

        mask_size = np.ceil(np.array(input_shape[0:2], dtype=float) /
                            upsample_size)
        mask_size = mask_size.astype(int)
        self.mask_size = mask_size
        mask = np.zeros(self.mask_size)
        pattern = np.zeros(input_shape)
        mask = np.expand_dims(mask, axis=2)

        mask_tanh = np.zeros_like(mask)
        pattern_tanh = np.zeros_like(pattern)

        # prepare mask related tensors
        self.mask_tanh_tensor = K.variable(mask_tanh)
        mask_tensor_unrepeat = (K.tanh(self.mask_tanh_tensor) /
                                (2 - self.epsilon) +
                                0.5)
        mask_tensor_unexpand = K.repeat_elements(
            mask_tensor_unrepeat,
            rep=self.img_color,
            axis=2)
        self.mask_tensor = K.expand_dims(mask_tensor_unexpand, axis=0)
        upsample_layer = UpSampling2D(
            size=(self.upsample_size, self.upsample_size))
        mask_upsample_tensor_uncrop = upsample_layer(self.mask_tensor)
        uncrop_shape = K.int_shape(mask_upsample_tensor_uncrop)[1:]
        cropping_layer = Cropping2D(
            cropping=((0, uncrop_shape[0] - self.input_shape[0]),
                      (0, uncrop_shape[1] - self.input_shape[1])))
        self.mask_upsample_tensor = cropping_layer(
            mask_upsample_tensor_uncrop)
        reverse_mask_tensor = (K.ones_like(self.mask_upsample_tensor) -
                               self.mask_upsample_tensor)

        def keras_preprocess(x_input, intensity_range):

            if intensity_range is 'raw':
                x_preprocess = x_input

            elif intensity_range is 'imagenet':
                # 'RGB'->'BGR'
                x_tmp = x_input[..., ::-1]
                # Zero-center by mean pixel
                mean = K.constant([[[103.939, 116.779, 123.68]]])
                x_preprocess = x_tmp - mean

            elif intensity_range is 'inception':
                x_preprocess = (x_input / 255.0 - 0.5) * 2.0

            elif intensity_range is 'mnist':
                x_preprocess = x_input / 255.0

            else:
                raise Exception('unknown intensity_range %s' % intensity_range)

            return x_preprocess

        def keras_reverse_preprocess(x_input, intensity_range):

            if intensity_range is 'raw':
                x_reverse = x_input

            elif intensity_range is 'imagenet':
                # Zero-center by mean pixel
                mean = K.constant([[[103.939, 116.779, 123.68]]])
                x_reverse = x_input + mean
                # 'BGR'->'RGB'
                x_reverse = x_reverse[..., ::-1]

            elif intensity_range is 'inception':
                x_reverse = (x_input / 2 + 0.5) * 255.0

            elif intensity_range is 'mnist':
                x_reverse = x_input * 255.0

            else:
                raise Exception('unknown intensity_range %s' % intensity_range)

            return x_reverse

        # prepare pattern related tensors
        self.pattern_tanh_tensor = K.variable(pattern_tanh)
        self.pattern_raw_tensor = (
            (K.tanh(self.pattern_tanh_tensor) / (2 - self.epsilon) + 0.5) *
            255.0)

        # prepare input image related tensors
        # ignore clip operation here
        # assume input image is already clipped into valid color range
        input_tensor = K.placeholder(model.input_shape)
        if self.raw_input_flag:
            input_raw_tensor = input_tensor
        else:
            input_raw_tensor = keras_reverse_preprocess(
                input_tensor, self.intensity_range)

        # IMPORTANT: MASK OPERATION IN RAW DOMAIN
        X_adv_raw_tensor = (
            reverse_mask_tensor * input_raw_tensor +
            self.mask_upsample_tensor * self.pattern_raw_tensor)

        X_adv_tensor = keras_preprocess(X_adv_raw_tensor, self.intensity_range)

        output_tensor = model(X_adv_tensor)
        y_true_tensor = K.placeholder(model.output_shape)

        self.loss_acc = categorical_accuracy(output_tensor, y_true_tensor)

        self.loss_ce = categorical_crossentropy(output_tensor, y_true_tensor)

        if self.regularization is None:
            self.loss_reg = K.constant(0)
        elif self.regularization is 'l1':
            self.loss_reg = (K.sum(K.abs(self.mask_upsample_tensor)) /
                             self.img_color)
        elif self.regularization is 'l2':
            self.loss_reg = K.sqrt(K.sum(K.square(self.mask_upsample_tensor)) /
                                   self.img_color)

        cost = self.init_cost
        self.cost_tensor = K.variable(cost)
        self.loss = self.loss_ce + self.loss_reg * self.cost_tensor

        self.opt = Adam(lr=self.lr, beta_1=0.5, beta_2=0.9)
        self.updates = self.opt.get_updates(
            params=[self.pattern_tanh_tensor, self.mask_tanh_tensor],
            loss=self.loss)
        self.train = K.function(
            [input_tensor, y_true_tensor],
            [self.loss_ce, self.loss_reg, self.loss, self.loss_acc],
            updates=self.updates)

        pass

    def reset_opt(self):

        K.set_value(self.opt.iterations, 0)
        for w in self.opt.weights:
            K.set_value(w, np.zeros(K.int_shape(w)))

        pass

    def reset_state(self, pattern_init, mask_init):

        print('resetting state')

        # setting cost
        if self.reset_cost_to_zero:
            self.cost = 0
        else:
            self.cost = self.init_cost
        K.set_value(self.cost_tensor, self.cost)

        # setting mask and pattern
        mask = np.array(mask_init)
        pattern = np.array(pattern_init)
        mask = np.clip(mask, self.mask_min, self.mask_max)
        pattern = np.clip(pattern, self.color_min, self.color_max)
        mask = np.expand_dims(mask, axis=2)

        # convert to tanh space
        mask_tanh = np.arctanh((mask - 0.5) * (2 - self.epsilon))
        pattern_tanh = np.arctanh((pattern / 255.0 - 0.5) * (2 - self.epsilon))
        print('mask_tanh', np.min(mask_tanh), np.max(mask_tanh))
        print('pattern_tanh', np.min(pattern_tanh), np.max(pattern_tanh))

        K.set_value(self.mask_tanh_tensor, mask_tanh)
        K.set_value(self.pattern_tanh_tensor, pattern_tanh)

        # resetting optimizer states
        self.reset_opt()

        pass

    def save_tmp_func(self, step):

        cur_mask = K.eval(self.mask_upsample_tensor)
        cur_mask = cur_mask[0, ..., 0]
        img_filename = (
            '%s/%s' % (self.tmp_dir, 'tmp_mask_step_%d.png' % step))
        dump_image(np.expand_dims(cur_mask, axis=2) * 255,
                                  img_filename,
                                  'png')

        cur_fusion = K.eval(self.mask_upsample_tensor *
                            self.pattern_raw_tensor)
        cur_fusion = cur_fusion[0, ...]
        img_filename = (
            '%s/%s' % (self.tmp_dir, 'tmp_fusion_step_%d.png' % step))
        dump_image(cur_fusion, img_filename, 'png')

        pass

    def visualize(self, gen, y_target, pattern_init, mask_init):

        # since we use a single optimizer repeatedly, we need to reset
        # optimzier's internal states before running the optimization
        self.reset_state(pattern_init, mask_init)

        # best optimization results
        mask_best = None
        mask_upsample_best = None
        pattern_best = None
        reg_best = float('inf')

        # logs and counters for adjusting balance cost
        logs = []
        cost_set_counter = 0
        cost_up_counter = 0
        cost_down_counter = 0
        cost_up_flag = False
        cost_down_flag = False

        # counter for early stop
        early_stop_counter = 0
        early_stop_reg_best = reg_best

        # vectorized target
        Y_target = to_categorical([y_target] * self.batch_size,
                                  self.num_classes)

        # loop start
        for step in range(self.steps):

            # record loss for all mini-batches
            loss_ce_list = []
            loss_reg_list = []
            loss_list = []
            loss_acc_list = []
            for idx in range(self.mini_batch):
                X_batch, _ = gen.next()
                if X_batch.shape[0] != Y_target.shape[0]:
                    Y_target = to_categorical([y_target] * X_batch.shape[0],
                                              self.num_classes)
                (loss_ce_value,
                    loss_reg_value,
                    loss_value,
                    loss_acc_value) = self.train([X_batch, Y_target])
                loss_ce_list.extend(list(loss_ce_value.flatten()))
                loss_reg_list.extend(list(loss_reg_value.flatten()))
                loss_list.extend(list(loss_value.flatten()))
                loss_acc_list.extend(list(loss_acc_value.flatten()))

            avg_loss_ce = np.mean(loss_ce_list)
            avg_loss_reg = np.mean(loss_reg_list)
            avg_loss = np.mean(loss_list)
            avg_loss_acc = np.mean(loss_acc_list)

            # check to save best mask or not
            if avg_loss_acc >= self.attack_succ_threshold and avg_loss_reg < reg_best:
                mask_best = K.eval(self.mask_tensor)
                mask_best = mask_best[0, ..., 0]
                mask_upsample_best = K.eval(self.mask_upsample_tensor)
                mask_upsample_best = mask_upsample_best[0, ..., 0]
                pattern_best = K.eval(self.pattern_raw_tensor)
                reg_best = avg_loss_reg

            # verbose
            if self.verbose != 0:
                if self.verbose == 2 or step % (self.steps // 10) == 0:
                    print('step: %3d, cost: %.2E, attack: %.3f, loss: %f, ce: %f, reg: %f, reg_best: %f' %
                          (step, Decimal(self.cost), avg_loss_acc, avg_loss,
                           avg_loss_ce, avg_loss_reg, reg_best))

            # save log
            logs.append((step,
                         avg_loss_ce, avg_loss_reg, avg_loss, avg_loss_acc,
                         reg_best, self.cost))

            # check early stop
            if self.early_stop:
                # only terminate if a valid attack has been found
                if reg_best < float('inf'):
                    if reg_best >= self.early_stop_threshold * early_stop_reg_best:
                        early_stop_counter += 1
                    else:
                        early_stop_counter = 0
                early_stop_reg_best = min(reg_best, early_stop_reg_best)

                if (cost_down_flag and
                        cost_up_flag and
                        early_stop_counter >= self.early_stop_patience):
                    print('early stop')
                    break

            # check cost modification
            if self.cost == 0 and avg_loss_acc >= self.attack_succ_threshold:
                cost_set_counter += 1
                if cost_set_counter >= self.patience:
                    self.cost = self.init_cost
                    K.set_value(self.cost_tensor, self.cost)
                    cost_up_counter = 0
                    cost_down_counter = 0
                    cost_up_flag = False
                    cost_down_flag = False
                    print('initialize cost to %.2E' % Decimal(self.cost))
            else:
                cost_set_counter = 0

            if avg_loss_acc >= self.attack_succ_threshold:
                cost_up_counter += 1
                cost_down_counter = 0
            else:
                cost_up_counter = 0
                cost_down_counter += 1

            if cost_up_counter >= self.patience:
                cost_up_counter = 0
                if self.verbose == 2:
                    print('up cost from %.2E to %.2E' %
                          (Decimal(self.cost),
                           Decimal(self.cost * self.cost_multiplier_up)))
                self.cost *= self.cost_multiplier_up
                K.set_value(self.cost_tensor, self.cost)
                cost_up_flag = True
            elif cost_down_counter >= self.patience:
                cost_down_counter = 0
                if self.verbose == 2:
                    print('down cost from %.2E to %.2E' %
                          (Decimal(self.cost),
                           Decimal(self.cost / self.cost_multiplier_down)))
                self.cost /= self.cost_multiplier_down
                K.set_value(self.cost_tensor, self.cost)
                cost_down_flag = True

            if self.save_tmp:
                self.save_tmp_func(step)

        # save the final version
        if mask_best is None or self.save_last:
            mask_best = K.eval(self.mask_tensor)
            mask_best = mask_best[0, ..., 0]
            mask_upsample_best = K.eval(self.mask_upsample_tensor)
            mask_upsample_best = mask_upsample_best[0, ..., 0]
            pattern_best = K.eval(self.pattern_raw_tensor)

        if self.return_logs:
            return pattern_best, mask_best, mask_upsample_best, logs
        else:
            return pattern_best, mask_best, mask_upsample_best

# %%
##############################
#        PARAMETERS          #
##############################

DEVICE = '0'  # specify which GPU to use

DATA_DIR = 'data'  # data folder
DATA_FILE = '/content/drive/MyDrive/data/clean_test_data.h5'  # dataset file
MODEL_DIR = 'models'  # model directory
MODEL_FILENAME = '/content/ml-cybersec-proj/models/sunglasses_bd_net.h5'  # model file
RESULT_DIR = '/content/drive/MyDrive/results_fin_4'  # directory for storing results
# image filename template for visualization results
IMG_FILENAME_TEMPLATE = 'visualize_%s_label_%d.png'

# input size
IMG_ROWS = 55
IMG_COLS = 47

IMG_COLOR = 3
INPUT_SHAPE = (IMG_ROWS, IMG_COLS, IMG_COLOR)

NUM_CLASSES = 1283  # total number of classes in the model- N+1
Y_TARGET = 12  # (optional) infected target label, used for prioritizing label scanning

INTENSITY_RANGE = 'raw'  # preprocessing method for the task, GTSRB uses raw pixel intensities #normalize later

# parameters for optimization
BATCH_SIZE = 20  #128  # batch size used for optimization
LR = 0.1  # learning rate
STEPS = 1000  # total optimization iterations
NB_SAMPLE = 1000  # number of samples in each mini batch
MINI_BATCH = NB_SAMPLE // BATCH_SIZE  # mini batch size used for early stop
INIT_COST = 1e-3  # initial weight used for balancing two objectives

REGULARIZATION = 'l1'  # reg term to control the mask's norm

ATTACK_SUCC_THRESHOLD = 0.99  # attack success threshold of the reversed attack
PATIENCE = 5  # patience for adjusting weight, number of mini batches
COST_MULTIPLIER = 2  # multiplier for auto-control of weight (COST)
SAVE_LAST = False  # whether to save the last result or best result

EARLY_STOP = True  # whether to early stop
EARLY_STOP_THRESHOLD = 1.0  # loss threshold for early stop
EARLY_STOP_PATIENCE = 5 * PATIENCE  # patience for early stop

UPSAMPLE_SIZE = 1  # size of the super pixel
MASK_SHAPE = np.ceil(np.array(INPUT_SHAPE[0:2], dtype=float) / UPSAMPLE_SIZE)
MASK_SHAPE = MASK_SHAPE.astype(int)
print(MASK_SHAPE)

# ##############################
# #      END PARAMETERS        #
# ##############################
# Out:
# [55 47]

# %%
def load_dataset(data_file=('%s' % (DATA_FILE))): # Load the

    dataset = load_data(data_file, keys=['data', 'label'])

    X_test = np.array(dataset['data'], dtype='float32')
    Y_test = np.array(dataset['label'], dtype='float32')

    print('X_test shape %s' % str(X_test.shape))
    print('Y_test shape %s' % str(Y_test.shape))

    return X_test, Y_test

# %%
def build_data_loader(X, Y):

    datagen = ImageDataGenerator() #Generate batches of tensor image data with real-time data augmentation.
    generator = datagen.flow(
        X, Y, batch_size=BATCH_SIZE)

    return generator

# %%
def visualize_trigger_w_mask(visualizer, gen, y_target,save_pattern_flag=True):  #actual reverse engineered trigger

    visualize_start_time = time.time()

    # initialize with random mask
    pattern = np.random.random(INPUT_SHAPE) * 255.0
    mask = np.random.random(MASK_SHAPE)

    # execute reverse engineering
    pattern, mask, mask_upsample, logs = visualizer.visualize(gen=gen, y_target=y_target, pattern_init=pattern, mask_init=mask)

    # meta data about the generated mask
    print('pattern, shape: %s, min: %f, max: %f' %
          (str(pattern.shape), np.min(pattern), np.max(pattern)))
    print('mask, shape: %s, min: %f, max: %f' %
          (str(mask.shape), np.min(mask), np.max(mask)))
    print('mask norm of label %d: %f' %
          (y_target, np.sum(np.abs(mask_upsample))))

    visualize_end_time = time.time()
    print('visualization cost %f seconds' %
          (visualize_end_time - visualize_start_time))

    if save_pattern_flag:
        save_pattern(pattern, mask_upsample, y_target)

    return pattern, mask_upsample, logs

# %%
def save_pattern(pattern, mask, y_target): #find and save pattern detected

    # create result dir
    if not os.path.exists(RESULT_DIR):
        os.mkdir(RESULT_DIR)

    img_filename = (
        '%s/%s' % (RESULT_DIR,
                   IMG_FILENAME_TEMPLATE % ('pattern', y_target)))
    dump_image(pattern, img_filename, 'png')

    img_filename = (
        '%s/%s' % (RESULT_DIR,
                   IMG_FILENAME_TEMPLATE % ('mask', y_target)))
    dump_image(np.expand_dims(mask, axis=2) * 255,img_filename,'png')

    fusion = np.multiply(pattern, np.expand_dims(mask, axis=2))
    img_filename = (
        '%s/%s' % (RESULT_DIR,
                   IMG_FILENAME_TEMPLATE % ('fusion', y_target)))
    dump_image(fusion, img_filename, 'png')

    pass

# %%
def start_analyse():

    print('loading dataset')
    X_test, Y_test = load_dataset()
    X_test = np.transpose(X_test, (0 , 2, 3, 1))
    #data, label = load_dataset()
    # transform numpy arrays into data generator
    test_generator = build_data_loader(X_test,Y_test)

    print('loading model')
    model_file = '%s' % (MODEL_FILENAME)
    print(model_file)
    model = load_model(model_file)

    # initialize visualizer
    visualizer = Visualizer(
        model, intensity_range=INTENSITY_RANGE, regularization=REGULARIZATION,
        input_shape=INPUT_SHAPE,
        init_cost=INIT_COST, steps=STEPS, lr=LR, num_classes=NUM_CLASSES,
        mini_batch=MINI_BATCH,
        upsample_size=UPSAMPLE_SIZE,
        attack_succ_threshold=ATTACK_SUCC_THRESHOLD,
        patience=PATIENCE, cost_multiplier=COST_MULTIPLIER,
        img_color=IMG_COLOR, batch_size=BATCH_SIZE, verbose=2,
        save_last=SAVE_LAST,
        early_stop=EARLY_STOP, early_stop_threshold=EARLY_STOP_THRESHOLD,
        early_stop_patience=EARLY_STOP_PATIENCE)

    log_mapping = {}

    # y_label list to analyze
    y_target_list = list(range(NUM_CLASSES))
    y_target_list.remove(Y_TARGET)
    y_target_list = [Y_TARGET] + y_target_list
    for y_target in y_target_list:

        print('processing label %d' % y_target)

        _, _, logs = visualize_trigger_w_mask(
            visualizer, test_generator, y_target=y_target,
            save_pattern_flag=True)

        log_mapping[y_target] = logs

    pass

# %%
start_time = time.time()
os.environ["CUDA_VISIBLE_DEVICES"] = DEVICE
fix_gpu_memory()
start_analyse()
elapsed_time = time.time() - start_time
print('elapsed time %s s' % elapsed_time)
# Out:
# Streaming output truncated to the last 5000 lines.
# step: 461, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 462, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 463, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 464, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 465, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 466, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 467, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 468, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 469, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 470, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 471, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 472, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 473, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 474, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 475, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 476, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 477, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 478, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 479, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 480, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 481, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 482, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 483, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 484, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 485, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 486, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 487, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 488, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 489, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 490, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 491, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 492, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 493, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 494, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 495, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 496, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 497, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 498, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 499, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 500, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 501, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 502, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 503, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 504, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 505, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 506, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 507, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 508, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 509, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 510, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 511, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 512, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 513, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 514, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 515, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 516, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 517, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 518, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 519, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 520, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 521, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 522, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 523, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 524, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 525, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 526, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 527, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 528, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 529, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 530, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 531, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 532, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 533, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 534, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 535, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 536, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 537, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 538, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 539, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 540, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 541, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 542, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 543, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 544, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 545, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 546, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 547, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 548, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 549, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 550, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 551, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 552, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 553, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 554, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 555, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 556, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 557, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 558, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 559, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 560, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 561, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 562, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 563, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 564, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 565, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 566, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 567, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 568, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 569, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 570, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 571, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 572, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 573, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 574, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 575, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 576, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 577, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 578, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 579, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 580, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 581, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 582, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 583, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 584, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 585, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 586, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 587, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 588, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 589, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 590, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 591, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 592, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 593, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 594, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 595, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 596, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 597, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 598, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 599, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 600, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 601, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 602, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 603, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 604, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 605, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 606, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 607, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 608, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 609, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 610, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 611, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 612, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 613, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 614, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 615, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 616, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 617, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 618, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 619, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 620, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 621, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 622, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 623, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 624, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 625, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 626, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 627, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 628, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 629, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 630, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 631, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 632, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 633, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 634, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 635, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 636, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 637, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 638, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 639, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 640, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 641, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 642, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 643, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 644, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 645, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 646, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 647, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 648, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 649, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 650, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 651, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 652, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 653, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 654, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 655, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 656, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 657, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 658, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 659, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 660, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 661, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 662, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 663, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 664, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 665, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 666, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 667, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 668, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 669, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 670, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 671, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 672, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 673, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 674, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 675, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 676, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 677, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 678, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 679, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 680, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 681, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 682, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 683, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 684, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 685, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 686, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 687, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 688, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 689, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 690, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 691, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 692, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 693, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 694, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 695, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 696, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 697, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 698, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 699, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 700, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 701, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 702, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 703, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 704, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 705, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 706, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 707, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 708, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 709, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 710, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 711, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 712, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 713, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 714, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 715, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 716, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 717, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 718, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 719, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 720, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 721, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 722, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 723, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 724, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 725, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 726, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 727, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 728, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 729, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 730, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 731, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 732, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 733, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 734, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 735, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 736, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 737, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 738, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 739, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 740, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 741, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 742, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 743, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 744, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 745, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 746, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 747, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 748, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 749, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 750, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 751, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 752, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 753, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 754, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 755, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 756, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 757, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 758, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 759, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 760, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 761, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 762, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 763, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 764, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 765, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 766, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 767, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 768, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 769, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 770, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 771, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 772, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 773, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 774, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 775, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 776, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 777, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 778, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 779, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 780, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 781, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 782, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 783, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 784, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 785, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 786, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 787, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 788, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 789, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 790, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 791, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 792, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 793, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 794, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 795, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 796, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 797, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 798, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 799, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 800, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 801, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 802, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 803, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 804, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 805, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 806, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 807, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 808, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 809, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 810, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 811, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 812, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 813, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 814, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 815, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 816, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 817, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 818, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 819, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 820, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 821, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 822, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 823, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 824, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 825, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 826, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 827, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 828, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 829, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 830, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 831, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 832, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 833, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 834, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 835, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 836, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 837, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 838, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 839, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 840, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 841, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 842, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 843, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 844, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 845, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 846, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 847, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 848, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 849, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 850, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 851, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 852, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 853, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 854, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 855, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 856, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 857, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 858, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 859, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 860, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 861, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 862, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 863, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 864, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 865, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 866, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 867, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 868, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 869, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 870, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 871, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 872, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 873, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 874, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 875, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 876, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 877, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 878, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 879, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 880, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 881, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 882, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# step: 883, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1082.935669, reg_best: inf
# ...
# step: 483, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 484, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 485, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 486, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 487, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 488, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 489, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 490, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 491, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 492, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 493, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 494, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 495, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 496, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 497, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 498, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 499, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 500, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 501, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 502, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 503, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 504, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 505, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 506, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 507, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 508, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 509, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 510, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 511, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 512, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 513, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 514, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 515, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 516, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 517, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 518, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 519, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 520, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 521, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 522, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 523, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 524, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 525, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 526, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 527, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 528, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 529, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 530, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 531, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 532, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 533, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 534, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 535, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 536, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 537, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 538, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 539, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 540, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 541, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 542, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 543, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 544, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 545, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 546, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 547, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 548, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 549, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 550, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 551, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 552, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 553, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 554, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 555, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 556, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 557, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 558, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 559, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 560, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 561, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 562, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 563, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 564, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 565, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 566, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 567, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 568, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 569, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 570, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 571, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 572, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 573, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 574, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 575, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 576, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 577, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 578, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 579, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 580, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 581, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 582, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 583, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 584, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 585, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 586, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 587, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 588, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 589, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 590, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 591, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 592, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 593, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 594, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 595, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 596, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 597, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 598, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# step: 599, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# down cost from 0.00E+00 to 0.00E+00
# step: 600, cost: 0.00E+00, attack: 0.000, loss: 16.118099, ce: 16.118099, reg: 1322.017944, reg_best: inf
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-3ad7ee11ccbc> in <module>()
#       2 os.environ["CUDA_VISIBLE_DEVICES"] = DEVICE
#       3 fix_gpu_memory()
# ----> 4 start_analyse()
#       5 elapsed_time = time.time() - start_time
#       6 print('elapsed time %s s' % elapsed_time)
#
# <ipython-input-15-610da4c9b439> in start_analyse()
#      39         _, _, logs = visualize_trigger_w_mask(
#      40             visualizer, test_generator, y_target=y_target,
# ---> 41             save_pattern_flag=True)
#      42
#      43         log_mapping[y_target] = logs
#
# <ipython-input-13-bbf096057b7c> in visualize_trigger_w_mask(visualizer, gen, y_target, save_pattern_flag)
#       8
#       9     # execute reverse engineering
# ---> 10     pattern, mask, mask_upsample, logs = visualizer.visualize(gen=gen, y_target=y_target, pattern_init=pattern, mask_init=mask)
#      11
#      12     # meta data about the generated mask
#
# <ipython-input-9-b2a2fe321798> in visualize(self, gen, y_target, pattern_init, mask_init)
#     335             loss_acc_list = []
#     336             for idx in range(self.mini_batch):
# --> 337                 X_batch, _ = gen.next()
#     338                 if X_batch.shape[0] != Y_target.shape[0]:
#     339                     Y_target = to_categorical([y_target] * X_batch.shape[0],
#
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/iterator.py in next(self)
#     114         # The transformation of images is not under thread lock
#     115         # so it can be done in parallel
# --> 116         return self._get_batches_of_transformed_samples(index_array)
#     117
#     118     def _get_batches_of_transformed_samples(self, index_array):
#
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/numpy_array_iterator.py in _get_batches_of_transformed_samples(self, index_array)
#     158         for i, j in enumerate(index_array):
#     159             x = self.x[j]
# --> 160             params = self.image_data_generator.get_random_transform(x.shape)
#     161             x = self.image_data_generator.apply_transform(
#     162                 x.astype(self.dtype), params)
#
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/image_data_generator.py in get_random_transform(self, img_shape, seed)
#     807                 2)
#     808
# --> 809         flip_horizontal = (np.random.random() < 0.5) * self.horizontal_flip
#     810         flip_vertical = (np.random.random() < 0.5) * self.vertical_flip
#     811
#
# KeyboardInterrupt:

# %%
import os #outlier detection
import sys
import time

import numpy as np
from tensorflow.keras.preprocessing import image


##############################
#        PARAMETERS          #
##############################

#RESULT_DIR = 'results'  # directory for storing results
#IMG_FILENAME_TEMPLATE = 'gtsrb_visualize_%s_label_%d.png'  # image filename template for visualization results

# input size
IMG_ROWS = 55
IMG_COLS = 47
IMG_COLOR = 3
INPUT_SHAPE = (IMG_ROWS, IMG_COLS, IMG_COLOR)

NUM_CLASSES = 1283  # total number of classes in the model

##############################
#      END PARAMETERS        #
##############################


def outlier_detection(l1_norm_list, idx_mapping):

    consistency_constant = 1.4826  # if normal distribution
    median = np.median(l1_norm_list)
    mad = consistency_constant * np.median(np.abs(l1_norm_list - median))
    min_mad = np.abs(np.min(l1_norm_list) - median) / mad

    print('median: %f, MAD: %f' % (median, mad))
    print('anomaly index: %f' % min_mad)

    flag_list = []
    for y_label in idx_mapping:
        if l1_norm_list[idx_mapping[y_label]] > median:
            continue
        if np.abs(l1_norm_list[idx_mapping[y_label]] - median) / mad > 2:
            flag_list.append((y_label, l1_norm_list[idx_mapping[y_label]]))

    if len(flag_list) > 0:
        flag_list = sorted(flag_list, key=lambda x: x[1])

    print('flagged label list: %s' %
          ', '.join(['%d: %2f' % (y_label, l_norm)
                     for y_label, l_norm in flag_list]))

    pass


def analyze_pattern_norm_dist():

    mask_flatten = []
    idx_mapping = {}

    for y_label in range(NUM_CLASSES):
        mask_filename = IMG_FILENAME_TEMPLATE % ('mask', y_label)
        if os.path.isfile('%s/%s' % (RESULT_DIR, mask_filename)):
            img = image.load_img(
                '%s/%s' % (RESULT_DIR, mask_filename),
                color_mode='grayscale',
                target_size=INPUT_SHAPE)
            mask = image.img_to_array(img)
            mask /= 255
            mask = mask[:, :, 0]

            mask_flatten.append(mask.flatten())

            idx_mapping[y_label] = len(mask_flatten) - 1

    l1_norm_list = [np.sum(np.abs(m)) for m in mask_flatten]

    print('%d labels found' % len(l1_norm_list))

    outlier_detection(l1_norm_list, idx_mapping)

    pass

# %%
#print('%s start' % sys.argv[0])
start_time = time.time()
analyze_pattern_norm_dist()
elapsed_time = time.time() - start_time
print('elapsed time %.2f s' % elapsed_time)
# Out:
# 191 labels found
# median: 1299.588257, MAD: 44.024460
# anomaly index: 27.610231
# flagged label list: 0: 84.062744, 90: 405.678467, 37: 1069.270630, 187: 1077.866699, 107: 1109.309814, 104: 1114.270752, 89: 1127.619629, 66: 1141.803955, 9: 1142.066650, 159: 1142.878418, 18: 1145.090332, 136: 1182.686279, 138: 1185.380371, 51: 1199.164795, 88: 1200.541260, 50: 1200.768677, 172: 1206.313721, 93: 1210.709717
# elapsed time 0.28 s
